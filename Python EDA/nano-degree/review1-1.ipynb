# %% [markdown]
# # 데이터 분석 관련 직무

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #   데이터 분석 관련 직무 스킬

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 출처: <러닝스푼즈-나노디그리> 윤기태 강의 자료
