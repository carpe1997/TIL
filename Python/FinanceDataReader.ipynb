# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'nanummyeongjo'
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True

# %%
# %%html
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>
# Out:
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>

# %%
pip install -U finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.31-py3-none-any.whl (17 kB)
# Collecting requests-file
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\82109\anaconda3\lib\site-packages (from finance-datareader) (1.2.4)
# Requirement already satisfied: tqdm in c:\users\82109\anaconda3\lib\site-packages (from finance-datareader) (4.50.2)
# Requirement already satisfied: requests>=2.3.0 in c:\users\82109\anaconda3\lib\site-packages (from finance-datareader) (2.24.0)
# Requirement already satisfied: lxml in c:\users\82109\anaconda3\lib\site-packages (from finance-datareader) (4.6.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\82109\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2020.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\82109\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\82109\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\82109\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\82109\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\82109\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82109\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\82109\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.25.11)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.31 requests-file-1.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.31'

# %%
import FinanceDataReader as fdr
import pandas as pd
# 한국거래소 상장종목 전체
df_krx = fdr.StockListing('KRX')
df_krx
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 7146  000547   KOSPI  흥국화재2우B                       NaN
# 7147  000545   KOSPI    흥국화재우                       NaN
# 7148  003280   KOSPI     흥아해운                    해상 운송업
# 7149  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7150  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 7146                             NaN         NaT         NaN
# 7147                             NaN         NaT         NaN
# 7148                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 7149                       설계 및 감리용역  2000-02-03         12월
# 7150  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                       HomePage Region
# 0       박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                      박대현         http://www.ajnet.co.kr  서울특별시
# 2        채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                      정기로   http://www.apsholdings.co.kr    경기도
# 4                      김영주     http://www.apsystems.co.kr    경기도
# ...                    ...                            ...    ...
# 7146                   NaN                            NaN    NaN
# 7147                   NaN                            NaN    NaN
# 7148                   이환구         http://www.heung-a.com  서울특별시
# 7149  정영균, 이목운, 허철호 (각자대표)          http://www.heerim.com  서울특별시
# 7150                   김주환          http://www.hims.co.kr  인천광역시
#
# [7151 rows x 10 columns]
