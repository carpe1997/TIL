# %% [markdown]
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
import pandas as pd
import numpy as np
import requests

# %%
url="https://finance.naver.com/api/sise/etfItemList.nhn"
print(url)
# Out:
# https://finance.naver.com/api/sise/etfItemList.nhn

# %% [markdown]
# ## Pandas를 통한 요청

# %%
pd.read_html(url)
#안된다.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5ad8eacc451f> in <module>
# ----> 1 pd.read_html(url)
#       2 #안된다.
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083     io = stringify_path(io)
#    1084
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     911     else:
#     912         assert retained is not None  # for mypy
# --> 913         raise retained
#     914
#     915     ret = []
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     891
#     892         try:
# --> 893             tables = p.parse_tables()
#     894         except ValueError as caught:
#     895             # if `io` is an io-like object, check if it's seekable
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     211         list of parsed (header, body, footer) tuples from tables.
#     212         """
# --> 213         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     214         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     215
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse_tables(self, doc, match, attrs)
#     541
#     542         if not tables:
# --> 543             raise ValueError("No tables found")
#     544
#     545         result = []
#
# ValueError: No tables found

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
import requests

# %%
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"resultCode":"success","result":{"etfItemList":[{"itemcode":"069500","etfTabCode":1,"itemname":"KODEX 200","nowVal":43955,"risefall":"2","changeVal":220,"changeRate":0.5,"nav":44047.0,"threeMonthEarnRate":7.4517,"quant":2655205,"amonut":116819,"marketSum":39933},{"itemcode":"153130","etfTabCode":6,"itemname":"KODEX 단기채권","nowVal":102805,"risefall":"5","changeVal":-10,"changeRate":-0.01,"nav":102803.0,"threeMonthEarnRate":0.0535,"quant":22011,"amonut":2262,"marketSum":24415},{"itemcode":"252670","etfTabCode":3,"itemname":"KODEX 200선물인버스2X","nowVal":1845,"risefall":"5","changeVal":-15,"changeRate":-0.81,"nav":1844.0,"threeMonthEarnRate":-15.262,"quant":146475126,"amonut":269418,"marketSum":22304},{"itemcode":"102110","etfTabCode":1,"itemname":"TIGER 200","nowVal":43985,"risefall":"2","changeVal":215,"changeRate":0.49,"nav":44081.0,"threeMonthEarnRate":7.4928,"quant":530566,"amonut":23370,"marketSum":22036},{"itemcode":"102780","etfTabCode":2,"itemname":"KODEX 삼성그룹","nowVal":10285,"risefall":"2","changeVal":15,"changeRate":0.15,"nav":10323.0,"threeMonthEarnRate":7.4492,"quant":265587,"amonut":2741,"marketSum":18852},{"itemcode":"214980","etfTabCode":6,"itemname":"KODEX 단기채권PLUS","nowVal":103095,"risefall":"5","changeVal":-10,"changeRate":-0.01,"nav":103091.0,"threeMonthEarnRate":0.0825,"quant":1216503,"amonut":125415,"marketSum":16316},{"itemcode":"273130","etfTabCode":6,"itemname":"KODEX 종합채권(AA-이상)액티브","nowVal":108660,"risefall":"5","changeVal":-200,"changeRate":-0.18,"nav":108610.0,"threeMonthEarnRate":-0.1697,"quant":5992,"amonut":650,"marketSum":14832},{"itemcode":"278530","etfTabCode":1,"itemname":"KODEX 200TR","nowVal":14390,"risefall":"2","changeVal":80,"changeRate":0.56,"nav":14403.0,"threeMonthEarnRate":7.4727,"quant":214703,"amonut":3086,"marketSum":14440},{"itemcode":"122630","etfTabCode":3,"itemname":"KODEX 레버리지","nowVal":29405,"risefall":"2","changeVal":300,"changeRate":1.03,"nav":29650.0,"threeMonthEarnRate":14.7673,"quant":16827137,"amonut":495960,"marketSum":14114},{"itemcode":"305720","etfTabCode":2,"itemname":"KODEX 2차전지산업","nowVal":19010,"risefall":"2","changeVal":60,"changeRate":0.32,"nav":19069.0,"threeMonthEarnRate":12.5096,"quant":567473,"amonut":10829,"marketSum":12851},{"itemcode":"278540","etfTabCode":1,"itemname":"KODEX MSCI Korea TR","nowVal":14095,"risefall":"2","changeVal":55,"changeRate":0.39,"nav":14136.0,"threeMonthEarnRate":5.8424,"quant":489545,"amonut":6905,"marketSum":12065},{"itemcode":"148020","etfTabCode":1,"itemname":"KBSTAR 200","nowVal":44020,"risefall":"2","changeVal":225,"changeRate":0.51,"nav":44107.0,"threeMonthEarnRate":7.4723,"quant":176559,"amonut":7784,"marketSum":11643},{"itemcode":"114800","etfTabCode":3,"itemname":"KODEX 인버스","nowVal":3675,"risefall":"5","changeVal":-20,"changeRate":-0.54,"nav":3679.0,"threeMonthEarnRate":-7.8554,"quant":29176518,"amonut":107164,"marketSum":11345},{"itemcode":"292150","etfTabCode":2,"itemname":"TIGER TOP10","nowVal":15065,"risefall":"2","changeVal":25,"changeRate":0.17,"nav":15066.0,"threeMonthEarnRate":4.9766,"quant":316716,"amonut":4774,"marketSum":9732},{"itemcode":"233740","etfTabCode":1,"itemname":"KODEX 코스닥150 레버리지","nowVal":14800,"risefall":"5","changeVal":-195,"changeRate":-1.3,"nav":14938.0,"threeMonthEarnRate":0.6038,"quant":6173504,"amonut":92869,"marketSum":9724},{"itemcode":"371460","etfTabCode":4,"itemname":"TIGER 차이나전기차SOLACTIVE","nowVal":13995,"risefall":"2","changeVal":65,"changeRate":0.47,"nav":null,"threeMonthEarnRate":38.538,"quant":2382368,"amonut":33174,"marketSum":9713},{"itemcode":"139260","etfTabCode":2,"itemname":"TIGER 200 IT","nowVal":38835,"risefall":"2","changeVal":215,"changeRate":0.56,"nav":38856.0,"threeMonthEarnRate":3.3559,"quant":366526,"amonut":14232,"marketSum":9414},{"itemcode":"157450","etfTabCode":6,"itemname":"TIGER 단기통안채","nowVal":100200,"risefall":"5","changeVal":-20,"changeRate":-0.02,"nav":100197.0,"threeMonthEarnRate":0.0998,"quant":4066,"amonut":407,"marketSum":9354},{"itemcode":"305540","etfT ...

# %%
headers={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36"}

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
etf_json=response.json()

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
etfItemList=etf_json["result"]["etfItemList"]
etfItemList
# Out:
# [{'itemcode': '069500',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200',
#   'nowVal': 43955,
#   'risefall': '2',
#   'changeVal': 220,
#   'changeRate': 0.5,
#   'nav': 44047.0,
#   'threeMonthEarnRate': 7.4517,
#   'quant': 2655205,
#   'amonut': 116819,
#   'marketSum': 39933},
#  {'itemcode': '153130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권',
#   'nowVal': 102805,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.01,
#   'nav': 102803.0,
#   'threeMonthEarnRate': 0.0535,
#   'quant': 22011,
#   'amonut': 2262,
#   'marketSum': 24415},
#  {'itemcode': '252670',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 200선물인버스2X',
#   'nowVal': 1845,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.81,
#   'nav': 1844.0,
#   'threeMonthEarnRate': -15.262,
#   'quant': 146475126,
#   'amonut': 269418,
#   'marketSum': 22304},
#  {'itemcode': '102110',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 200',
#   'nowVal': 43985,
#   'risefall': '2',
#   'changeVal': 215,
#   'changeRate': 0.49,
#   'nav': 44081.0,
#   'threeMonthEarnRate': 7.4928,
#   'quant': 530566,
#   'amonut': 23370,
#   'marketSum': 22036},
#  {'itemcode': '102780',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 삼성그룹',
#   'nowVal': 10285,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.15,
#   'nav': 10323.0,
#   'threeMonthEarnRate': 7.4492,
#   'quant': 265587,
#   'amonut': 2741,
#   'marketSum': 18852},
#  {'itemcode': '214980',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권PLUS',
#   'nowVal': 103095,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.01,
#   'nav': 103091.0,
#   'threeMonthEarnRate': 0.0825,
#   'quant': 1216503,
#   'amonut': 125415,
#   'marketSum': 16316},
#  {'itemcode': '273130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 종합채권(AA-이상)액티브',
#   'nowVal': 108660,
#   'risefall': '5',
#   'changeVal': -200,
#   'changeRate': -0.18,
#   'nav': 108610.0,
#   'threeMonthEarnRate': -0.1697,
#   'quant': 5992,
#   'amonut': 650,
#   'marketSum': 14832},
#  {'itemcode': '278530',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200TR',
#   'nowVal': 14390,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.56,
#   'nav': 14403.0,
#   'threeMonthEarnRate': 7.4727,
#   'quant': 214703,
#   'amonut': 3086,
#   'marketSum': 14440},
#  {'itemcode': '122630',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 레버리지',
#   'nowVal': 29405,
#   'risefall': '2',
#   'changeVal': 300,
#   'changeRate': 1.03,
#   'nav': 29650.0,
#   'threeMonthEarnRate': 14.7673,
#   'quant': 16827137,
#   'amonut': 495960,
#   'marketSum': 14114},
#  {'itemcode': '305720',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 2차전지산업',
#   'nowVal': 19010,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.32,
#   'nav': 19069.0,
#   'threeMonthEarnRate': 12.5096,
#   'quant': 567473,
#   'amonut': 10829,
#   'marketSum': 12851},
#  {'itemcode': '278540',
#   'etfTabCode': 1,
#   'itemname': 'KODEX MSCI Korea TR',
#   'nowVal': 14095,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.39,
#   'nav': 14136.0,
#   'threeMonthEarnRate': 5.8424,
#   'quant': 489545,
#   'amonut': 6905,
#   'marketSum': 12065},
#  {'itemcode': '148020',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 200',
#   'nowVal': 44020,
#   'risefall': '2',
#   'changeVal': 225,
#   'changeRate': 0.51,
#   'nav': 44107.0,
#   'threeMonthEarnRate': 7.4723,
#   'quant': 176559,
#   'amonut': 7784,
#   'marketSum': 11643},
#  {'itemcode': '114800',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 인버스',
#   'nowVal': 3675,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.54,
#   'nav': 3679.0,
#   'threeMonthEarnRate': -7.8554,
#   'quant': 29176518,
#   'amonut': 107164,
#   'marketSum': 11345},
#  {'itemcode': '292150',
#   'etfTabCode': 2,
#   'itemname': 'TIGER TOP10',
#   'nowVal': 15065,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.17,
#   'nav': 15066.0,
#   'threeMonthEarnRate': 4.9766,
#   'quant': 316716,
#   'amonut': 4774,
#   'marketSum': 9732},
#  {'itemcode': '233740',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥150 레버리지',
#   'nowVal': 14800,
#   'risefall': '5',
#   'changeVal': -195,
#   'changeRate': -1.3,
#   'nav': 14938.0,
#   'threeMonthEarnRate': 0.6038,
#   'quant': 6173504,
#   'amonut': 92869,
#   'marketSum': 9724},
#  {'itemcode': '371460',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나전기차SOLACTIVE',
#   'nowVal': 13995,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.47,
#   'nav': None,
#   'threeMonthEarnRate': 38.538,
#   'quant': 2382368,
#   'amonut': 33174,
#   'marketSum': 9713},
#  {'itemcode': '139260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 IT',
#   'nowVal': 38835,
#   'risefall': '2',
#   'changeVal': 215,
#   'changeRate': 0.56,
#   'nav': 38856.0,
#   'threeMonthEarnRate': 3.3559,
#   'quant': 366526,
#   'amonut': 14232,
#   'marketSum': 9414},
#  {'itemcode': '157450',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기통안채',
#   'nowVal': 100200,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.02,
#   'nav': 100197.0,
#   'threeMonthEarnRate': 0.0998,
#   'quant': 4066,
#   'amonut': 407,
#   'marketSum': 9354},
#  {'itemcode': '305540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 2차전지테마',
#   'nowVal': 18320,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.35,
#   'nav': 18387.0,
#   'threeMonthEarnRate': 17.356,
#   'quant': 612822,
#   'amonut': 11283,
#   'marketSum': 8958},
#  {'itemcode': '152100',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 200',
#   'nowVal': 44365,
#   'risefall': '2',
#   'changeVal': 240,
#   'changeRate': 0.54,
#   'nav': 44465.0,
#   'threeMonthEarnRate': 7.4934,
#   'quant': 70010,
#   'amonut': 3107,
#   'marketSum': 8740},
#  {'itemcode': '364980',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX2차전지K-뉴딜',
#   'nowVal': 17060,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.12,
#   'nav': 17083.0,
#   'threeMonthEarnRate': 17.7934,
#   'quant': 635315,
#   'amonut': 10877,
#   'marketSum': 8317},
#  {'itemcode': '133690',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥100',
#   'nowVal': 72650,
#   'risefall': '5',
#   'changeVal': -190,
#   'changeRate': -0.26,
#   'nav': None,
#   'threeMonthEarnRate': 10.0086,
#   'quant': 96063,
#   'amonut': 6987,
#   'marketSum': 7628},
#  {'itemcode': '105190',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 200',
#   'nowVal': 44055,
#   'risefall': '2',
#   'changeVal': 215,
#   'changeRate': 0.49,
#   'nav': 44139.0,
#   'threeMonthEarnRate': 7.5089,
#   'quant': 237862,
#   'amonut': 10491,
#   'marketSum': 7445},
#  {'itemcode': '310970',
#   'etfTabCode': 1,
#   'itemname': 'TIGER MSCI Korea TR',
#   'nowVal': 17765,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.37,
#   'nav': 17762.0,
#   'threeMonthEarnRate': 6.1469,
#   'quant': 5786,
#   'amonut': 102,
#   'marketSum': 7372},
#  {'itemcode': '293180',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200',
#   'nowVal': 43975,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 0.48,
#   'nav': 44057.0,
#   'threeMonthEarnRate': 7.4093,
#   'quant': 85822,
#   'amonut': 3778,
#   'marketSum': 6618},
#  {'itemcode': '229200',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥 150',
#   'nowVal': 14300,
#   'risefall': '5',
#   'changeVal': -110,
#   'changeRate': -0.76,
#   'nav': 14451.0,
#   'threeMonthEarnRate': 0.6003,
#   'quant': 1096194,
#   'amonut': 15820,
#   'marketSum': 5970},
#  {'itemcode': '314250',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국FANG플러스(H)',
#   'nowVal': 28245,
#   'risefall': '2',
#   'changeVal': 245,
#   'changeRate': 0.88,
#   'nav': None,
#   'threeMonthEarnRate': 6.0806,
#   'quant': 418079,
#   'amonut': 11812,
#   'marketSum': 5960},
#  {'itemcode': '069660',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200',
#   'nowVal': 43965,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 0.48,
#   'nav': 44041.0,
#   'threeMonthEarnRate': 7.5457,
#   'quant': 5711,
#   'amonut': 250,
#   'marketSum': 5847},
#  {'itemcode': '091180',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 자동차',
#   'nowVal': 25035,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.5,
#   'nav': 25032.0,
#   'threeMonthEarnRate': 10.2261,
#   'quant': 426697,
#   'amonut': 10633,
#   'marketSum': 5320},
#  {'itemcode': '294400',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200TR',
#   'nowVal': 52245,
#   'risefall': '2',
#   'changeVal': 260,
#   'changeRate': 0.5,
#   'nav': 52339.0,
#   'threeMonthEarnRate': 7.5069,
#   'quant': 7788,
#   'amonut': 406,
#   'marketSum': 5068},
#  {'itemcode': '364960',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX BBIG K-뉴딜',
#   'nowVal': 13070,
#   'risefall': '5',
#   'changeVal': -95,
#   'changeRate': -0.72,
#   'nav': 13072.0,
#   'threeMonthEarnRate': 10.7698,
#   'quant': 249253,
#   'amonut': 3268,
#   'marketSum': 4967},
#  {'itemcode': '315930',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Top5PlusTR',
#   'nowVal': 20260,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 0.55,
#   'nav': 20336.0,
#   'threeMonthEarnRate': 3.4394,
#   'quant': 9312,
#   'amonut': 188,
#   'marketSum': 4700},
#  {'itemcode': '295040',
#   'etfTabCode': 1,
#   'itemname': 'SMART 200TR',
#   'nowVal': 14960,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.5,
#   'nav': 14987.0,
#   'threeMonthEarnRate': 7.4729,
#   'quant': 42862,
#   'amonut': 641,
#   'marketSum': 4578},
#  {'itemcode': '251340',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 코스닥150선물인버스',
#   'nowVal': 4475,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.67,
#   'nav': 4474.0,
#   'threeMonthEarnRate': -2.0926,
#   'quant': 12827822,
#   'amonut': 56914,
#   'marketSum': 4386},
#  {'itemcode': '282000',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 국고채3년선물인버스',
#   'nowVal': 100105,
#   'risefall': '2',
#   'changeVal': 200,
#   'changeRate': 0.2,
#   'nav': 100134.0,
#   'threeMonthEarnRate': 0.3566,
#   'quant': 9,
#   'amonut': 0,
#   'marketSum': 4039},
#  {'itemcode': '290130',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR ESG사회책임투자',
#   'nowVal': 14310,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.35,
#   'nav': 14373.0,
#   'threeMonthEarnRate': 5.4499,
#   'quant': 1088413,
#   'amonut': 15591,
#   'marketSum': 3513},
#  {'itemcode': '360750',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500',
#   'nowVal': 12150,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.21,
#   'nav': None,
#   'threeMonthEarnRate': 9.0852,
#   'quant': 441854,
#   'amonut': 5375,
#   'marketSum': 3511},
#  {'itemcode': '226490',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스피',
#   'nowVal': 33055,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.26,
#   'nav': 33162.0,
#   'threeMonthEarnRate': 9.6441,
#   'quant': 47912,
#   'amonut': 1584,
#   'marketSum': 3504},
#  {'itemcode': '385540',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#   'nowVal': 99990,
#   'risefall': '5',
#   'changeVal': -300,
#   'changeRate': -0.3,
#   'nav': 99931.0,
#   'threeMonthEarnRate': None,
#   'quant': 7,
#   'amonut': 0,
#   'marketSum': 3451},
#  {'itemcode': '332500',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 200TR',
#   'nowVal': 26810,
#   'risefall': '2',
#   'changeVal': 145,
#   'changeRate': 0.54,
#   'nav': 26853.0,
#   'threeMonthEarnRate': 7.4984,
#   'quant': 5177,
#   'amonut': 138,
#   'marketSum': 3432},
#  {'itemcode': '357870',
#   'etfTabCode': 7,
#   'itemname': 'TIGER CD금리투자KIS(합성)',
#   'nowVal': 50345,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 50338.0,
#   'threeMonthEarnRate': 0.199,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 3155},
#  {'itemcode': '192090',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300',
#   'nowVal': 12085,
#   'risefall': '2',
#   'changeVal': 160,
#   'changeRate': 1.34,
#   'nav': None,
#   'threeMonthEarnRate': 5.718,
#   'quant': 276147,
#   'amonut': 3322,
#   'marketSum': 3070},
#  {'itemcode': '381180',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국필라델피아반도체나스닥',
#   'nowVal': 9910,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.92,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 751463,
#   'amonut': 7447,
#   'marketSum': 2938},
#  {'itemcode': '091170',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 은행',
#   'nowVal': 7755,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 2.17,
#   'nav': 7775.0,
#   'threeMonthEarnRate': 13.4359,
#   'quant': 1772691,
#   'amonut': 13685,
#   'marketSum': 2896},
#  {'itemcode': '332940',
#   'etfTabCode': 1,
#   'itemname': 'HANARO MSCI Korea TR',
#   'nowVal': 17740,
#   'risefall': '2',
#   'changeVal': 135,
#   'changeRate': 0.77,
#   'nav': 17739.0,
#   'threeMonthEarnRate': 6.2141,
#   'quant': 91,
#   'amonut': 1,
#   'marketSum': 2874},
#  {'itemcode': '251350',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 선진국MSCI World',
#   'nowVal': 19165,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': None,
#   'threeMonthEarnRate': 8.2156,
#   'quant': 28506,
#   'amonut': 546,
#   'marketSum': 2856},
#  {'itemcode': '367770',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn수소경제테마',
#   'nowVal': 12950,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.62,
#   'nav': 12951.0,
#   'threeMonthEarnRate': 3.4981,
#   'quant': 137241,
#   'amonut': 1774,
#   'marketSum': 2739},
#  {'itemcode': '275980',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#   'nowVal': 18625,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 0.98,
#   'nav': None,
#   'threeMonthEarnRate': 6.3112,
#   'quant': 60853,
#   'amonut': 1130,
#   'marketSum': 2719},
#  {'itemcode': '091160',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 반도체',
#   'nowVal': 37830,
#   'risefall': '2',
#   'changeVal': 440,
#   'changeRate': 1.18,
#   'nav': 37940.0,
#   'threeMonthEarnRate': 1.9634,
#   'quant': 177985,
#   'amonut': 6722,
#   'marketSum': 2705},
#  {'itemcode': '190620',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 단기통안채',
#   'nowVal': 100315,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.01,
#   'nav': 100312.0,
#   'threeMonthEarnRate': 0.0997,
#   'quant': 767,
#   'amonut': 76,
#   'marketSum': 2647},
#  {'itemcode': '261220',
#   'etfTabCode': 5,
#   'itemname': 'KODEX WTI원유선물(H)',
#   'nowVal': 11035,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': None,
#   'threeMonthEarnRate': 26.1863,
#   'quant': 448836,
#   'amonut': 4952,
#   'marketSum': 2588},
#  {'itemcode': '168580',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 중국본토CSI300',
#   'nowVal': 32235,
#   'risefall': '2',
#   'changeVal': 315,
#   'changeRate': 0.99,
#   'nav': None,
#   'threeMonthEarnRate': 5.8355,
#   'quant': 14975,
#   'amonut': 481,
#   'marketSum': 2579},
#  {'itemcode': '385550',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#   'nowVal': 99895,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.03,
#   'nav': 99886.0,
#   'threeMonthEarnRate': None,
#   'quant': 313,
#   'amonut': 31,
#   'marketSum': 2502},
#  {'itemcode': '272580',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기채권액티브',
#   'nowVal': 50075,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.03,
#   'nav': 50068.0,
#   'threeMonthEarnRate': 0.0299,
#   'quant': 2197,
#   'amonut': 110,
#   'marketSum': 2418},
#  {'itemcode': '132030',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 골드선물(H)',
#   'nowVal': 12070,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.04,
#   'nav': None,
#   'threeMonthEarnRate': 2.2891,
#   'quant': 152922,
#   'amonut': 1843,
#   'marketSum': 2390},
#  {'itemcode': '360200',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 미국S&P500',
#   'nowVal': 12230,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.24,
#   'nav': None,
#   'threeMonthEarnRate': 9.201,
#   'quant': 182010,
#   'amonut': 2229,
#   'marketSum': 2373},
#  {'itemcode': '143850',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500선물(H)',
#   'nowVal': 49750,
#   'risefall': '2',
#   'changeVal': 190,
#   'changeRate': 0.38,
#   'nav': None,
#   'threeMonthEarnRate': 8.8393,
#   'quant': 57879,
#   'amonut': 2880,
#   'marketSum': 2338},
#  {'itemcode': '332930',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200TR',
#   'nowVal': 52300,
#   'risefall': '2',
#   'changeVal': 320,
#   'changeRate': 0.62,
#   'nav': 52378.0,
#   'threeMonthEarnRate': 7.5188,
#   'quant': 21377,
#   'amonut': 1117,
#   'marketSum': 2275},
#  {'itemcode': '371160',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나항셍테크',
#   'nowVal': 10385,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 1.76,
#   'nav': None,
#   'threeMonthEarnRate': 0.5914,
#   'quant': 544088,
#   'amonut': 5610,
#   'marketSum': 2274},
#  {'itemcode': '196230',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 단기통안채',
#   'nowVal': 104445,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.02,
#   'nav': 104446.0,
#   'threeMonthEarnRate': 0.115,
#   'quant': 579441,
#   'amonut': 60525,
#   'marketSum': 2229},
#  {'itemcode': '232080',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스닥150',
#   'nowVal': 14520,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -0.68,
#   'nav': 14650.0,
#   'threeMonthEarnRate': 0.5502,
#   'quant': 368210,
#   'amonut': 5375,
#   'marketSum': 2134},
#  {'itemcode': '245710',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 베트남VN30(합성)',
#   'nowVal': 21590,
#   'risefall': '5',
#   'changeVal': -110,
#   'changeRate': -0.51,
#   'nav': None,
#   'threeMonthEarnRate': 29.6296,
#   'quant': 133660,
#   'amonut': 2893,
#   'marketSum': 2029},
#  {'itemcode': '161510',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 고배당주',
#   'nowVal': 12750,
#   'risefall': '2',
#   'changeVal': 250,
#   'changeRate': 2.0,
#   'nav': 12790.0,
#   'threeMonthEarnRate': 13.5228,
#   'quant': 263785,
#   'amonut': 3350,
#   'marketSum': 1993},
#  {'itemcode': '302450',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스피',
#   'nowVal': 33080,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.23,
#   'nav': 33178.0,
#   'threeMonthEarnRate': 9.4802,
#   'quant': 9060,
#   'amonut': 299,
#   'marketSum': 1919},
#  {'itemcode': '278240',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150선물레버리지',
#   'nowVal': 15075,
#   'risefall': '5',
#   'changeVal': -170,
#   'changeRate': -1.12,
#   'nav': 15079.0,
#   'threeMonthEarnRate': 1.1276,
#   'quant': 14915,
#   'amonut': 228,
#   'marketSum': 1826},
#  {'itemcode': '326240',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR IT플러스',
#   'nowVal': 22460,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.07,
#   'nav': 22540.0,
#   'threeMonthEarnRate': 6.6986,
#   'quant': 207172,
#   'amonut': 4660,
#   'marketSum': 1819},
#  {'itemcode': '272560',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 단기국공채액티브',
#   'nowVal': 102005,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.03,
#   'nav': 102007.0,
#   'threeMonthEarnRate': 0.1423,
#   'quant': 620251,
#   'amonut': 63279,
#   'marketSum': 1773},
#  {'itemcode': '381170',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국테크TOP10 INDXX',
#   'nowVal': 10580,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.61,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 1002201,
#   'amonut': 10606,
#   'marketSum': 1772},
#  {'itemcode': '267770',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 200선물레버리지',
#   'nowVal': 22210,
#   'risefall': '2',
#   'changeVal': 200,
#   'changeRate': 0.91,
#   'nav': 22229.0,
#   'threeMonthEarnRate': 15.6594,
#   'quant': 293197,
#   'amonut': 6527,
#   'marketSum': 1732},
#  {'itemcode': '150460',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 중국소비테마',
#   'nowVal': 9335,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.21,
#   'nav': 9329.0,
#   'threeMonthEarnRate': 13.9867,
#   'quant': 60175,
#   'amonut': 561,
#   'marketSum': 1703},
#  {'itemcode': '270810',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150',
#   'nowVal': 14190,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -0.7,
#   'nav': 14324.0,
#   'threeMonthEarnRate': 0.4569,
#   'quant': 15872,
#   'amonut': 227,
#   'marketSum': 1663},
#  {'itemcode': '367380',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 미국나스닥100',
#   'nowVal': 12475,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.16,
#   'nav': None,
#   'threeMonthEarnRate': 9.8944,
#   'quant': 136568,
#   'amonut': 1704,
#   'marketSum': 1609},
#  {'itemcode': '143860',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 헬스케어',
#   'nowVal': 44305,
#   'risefall': '5',
#   'changeVal': -505,
#   'changeRate': -1.13,
#   'nav': 44502.0,
#   'threeMonthEarnRate': -0.3115,
#   'quant': 43031,
#   'amonut': 1925,
#   'marketSum': 1498},
#  {'itemcode': '091230',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 반도체',
#   'nowVal': 38770,
#   'risefall': '2',
#   'changeVal': 475,
#   'changeRate': 1.24,
#   'nav': 38844.0,
#   'threeMonthEarnRate': 1.9514,
#   'quant': 94305,
#   'amonut': 3647,
#   'marketSum': 1497},
#  {'itemcode': '148070',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 국고채10년',
#   'nowVal': 120325,
#   'risefall': '5',
#   'changeVal': -360,
#   'changeRate': -0.3,
#   'nav': 120185.0,
#   'threeMonthEarnRate': -0.1738,
#   'quant': 2666,
#   'amonut': 320,
#   'marketSum': 1456},
#  {'itemcode': '298770',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 한국대만IT프리미어',
#   'nowVal': 20365,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.27,
#   'nav': None,
#   'threeMonthEarnRate': 3.7865,
#   'quant': 25864,
#   'amonut': 526,
#   'marketSum': 1446},
#  {'itemcode': '138540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 현대차그룹+펀더멘털',
#   'nowVal': 28685,
#   'risefall': '2',
#   'changeVal': 145,
#   'changeRate': 0.51,
#   'nav': 28795.0,
#   'threeMonthEarnRate': 13.227,
#   'quant': 58279,
#   'amonut': 1673,
#   'marketSum': 1365},
#  {'itemcode': '182480',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#   'nowVal': 14730,
#   'risefall': '5',
#   'changeVal': -60,
#   'changeRate': -0.41,
#   'nav': None,
#   'threeMonthEarnRate': 13.6992,
#   'quant': 38929,
#   'amonut': 572,
#   'marketSum': 1355},
#  {'itemcode': '204480',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#   'nowVal': 33515,
#   'risefall': '2',
#   'changeVal': 915,
#   'changeRate': 2.81,
#   'nav': None,
#   'threeMonthEarnRate': 9.6351,
#   'quant': 109071,
#   'amonut': 3622,
#   'marketSum': 1274},
#  {'itemcode': '283580',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 중국본토CSI300',
#   'nowVal': 14585,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 1.46,
#   'nav': None,
#   'threeMonthEarnRate': 5.4272,
#   'quant': 41169,
#   'amonut': 596,
#   'marketSum': 1254},
#  {'itemcode': '328370',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스피TR',
#   'nowVal': 16555,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.49,
#   'nav': 16558.0,
#   'threeMonthEarnRate': 9.7967,
#   'quant': 16839,
#   'amonut': 277,
#   'marketSum': 1250},
#  {'itemcode': '219480',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500선물(H)',
#   'nowVal': 20480,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.39,
#   'nav': None,
#   'threeMonthEarnRate': 8.8871,
#   'quant': 43823,
#   'amonut': 897,
#   'marketSum': 1249},
#  {'itemcode': '176950',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국채선물10년인버스',
#   'nowVal': 47235,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 0.39,
#   'nav': 47255.0,
#   'threeMonthEarnRate': 0.1596,
#   'quant': 566,
#   'amonut': 26,
#   'marketSum': 1241},
#  {'itemcode': '372330',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나항셍테크',
#   'nowVal': 10405,
#   'risefall': '2',
#   'changeVal': 160,
#   'changeRate': 1.56,
#   'nav': None,
#   'threeMonthEarnRate': 0.5891,
#   'quant': 313754,
#   'amonut': 3245,
#   'marketSum': 1228},
#  {'itemcode': '136340',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 중기우량회사채',
#   'nowVal': 104955,
#   'risefall': '5',
#   'changeVal': -115,
#   'changeRate': -0.11,
#   'nav': 104966.0,
#   'threeMonthEarnRate': -0.1284,
#   'quant': 1861,
#   'amonut': 195,
#   'marketSum': 1196},
#  {'itemcode': '367760',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn5G테크',
#   'nowVal': 11520,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 1.05,
#   'nav': 11521.0,
#   'threeMonthEarnRate': 0.0526,
#   'quant': 156793,
#   'amonut': 1805,
#   'marketSum': 1187},
#  {'itemcode': '273140',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기변동금리부채권액티브',
#   'nowVal': 102565,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 102570.0,
#   'threeMonthEarnRate': 0.0878,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 1139},
#  {'itemcode': '252710',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 200선물인버스2X',
#   'nowVal': 1915,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.78,
#   'nav': 1914.0,
#   'threeMonthEarnRate': -14.978,
#   'quant': 3745448,
#   'amonut': 7138,
#   'marketSum': 1138},
#  {'itemcode': '368190',
#   'etfTabCode': 2,
#   'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#   'nowVal': 13415,
#   'risefall': '5',
#   'changeVal': -215,
#   'changeRate': -1.58,
#   'nav': 13418.0,
#   'threeMonthEarnRate': 11.0748,
#   'quant': 73743,
#   'amonut': 994,
#   'marketSum': 1127},
#  {'itemcode': '108450',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 삼성그룹섹터가중',
#   'nowVal': 17010,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 17027.0,
#   'threeMonthEarnRate': 10.7782,
#   'quant': 4143,
#   'amonut': 70,
#   'marketSum': 1123},
#  {'itemcode': '139280',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 경기방어',
#   'nowVal': 12805,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.12,
#   'nav': 12801.0,
#   'threeMonthEarnRate': 6.4872,
#   'quant': 34955,
#   'amonut': 449,
#   'marketSum': 1122},
#  {'itemcode': '233160',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스닥150 레버리지',
#   'nowVal': 15735,
#   'risefall': '5',
#   'changeVal': -220,
#   'changeRate': -1.38,
#   'nav': 15874.0,
#   'threeMonthEarnRate': 0.6307,
#   'quant': 75999,
#   'amonut': 1217,
#   'marketSum': 1078},
#  {'itemcode': '329200',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 부동산인프라고배당',
#   'nowVal': 5910,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.68,
#   'nav': 5911.0,
#   'threeMonthEarnRate': 15.7334,
#   'quant': 86721,
#   'amonut': 511,
#   'marketSum': 1064},
#  {'itemcode': '325010',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Fn성장',
#   'nowVal': 18910,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.13,
#   'nav': 18905.0,
#   'threeMonthEarnRate': 5.5815,
#   'quant': 1186,
#   'amonut': 22,
#   'marketSum': 1059},
#  {'itemcode': '144600',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 은선물(H)',
#   'nowVal': 5400,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.84,
#   'nav': None,
#   'threeMonthEarnRate': 2.6845,
#   'quant': 383606,
#   'amonut': 2064,
#   'marketSum': 1042},
#  {'itemcode': '225040',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#   'nowVal': 31160,
#   'risefall': '2',
#   'changeVal': 215,
#   'changeRate': 0.69,
#   'nav': None,
#   'threeMonthEarnRate': 17.4829,
#   'quant': 11863,
#   'amonut': 370,
#   'marketSum': 1028},
#  {'itemcode': '156080',
#   'etfTabCode': 1,
#   'itemname': 'KODEX MSCI Korea',
#   'nowVal': 20500,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.12,
#   'nav': 20584.0,
#   'threeMonthEarnRate': 6.11,
#   'quant': 335,
#   'amonut': 6,
#   'marketSum': 1025},
#  {'itemcode': '325020',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 배당가치',
#   'nowVal': 14030,
#   'risefall': '2',
#   'changeVal': 200,
#   'changeRate': 1.45,
#   'nav': 14031.0,
#   'threeMonthEarnRate': 10.2079,
#   'quant': 2835,
#   'amonut': 39,
#   'marketSum': 1024},
#  {'itemcode': '228800',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 여행레저',
#   'nowVal': 5440,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 1.4,
#   'nav': 5424.0,
#   'threeMonthEarnRate': 10.2774,
#   'quant': 367674,
#   'amonut': 2001,
#   'marketSum': 987},
#  {'itemcode': '376410',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 탄소효율그린뉴딜',
#   'nowVal': 10490,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.19,
#   'nav': 10524.0,
#   'threeMonthEarnRate': 7.2745,
#   'quant': 19081,
#   'amonut': 200,
#   'marketSum': 976},
#  {'itemcode': '117700',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 건설',
#   'nowVal': 3915,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.25,
#   'nav': 3914.0,
#   'threeMonthEarnRate': 21.3667,
#   'quant': 1129913,
#   'amonut': 4470,
#   'marketSum': 940},
#  {'itemcode': '114260',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국고채3년',
#   'nowVal': 57770,
#   'risefall': '5',
#   'changeVal': -165,
#   'changeRate': -0.28,
#   'nav': 57846.0,
#   'threeMonthEarnRate': -0.1638,
#   'quant': 8461,
#   'amonut': 488,
#   'marketSum': 936},
#  {'itemcode': '371470',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#   'nowVal': 13275,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.72,
#   'nav': None,
#   'threeMonthEarnRate': 19.33,
#   'quant': 50166,
#   'amonut': 664,
#   'marketSum': 919},
#  {'itemcode': '364970',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX바이오K-뉴딜',
#   'nowVal': 10490,
#   'risefall': '5',
#   'changeVal': -185,
#   'changeRate': -1.73,
#   'nav': 10508.0,
#   'threeMonthEarnRate': 5.432,
#   'quant': 167529,
#   'amonut': 1780,
#   'marketSum': 881},
#  {'itemcode': '368590',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국나스닥100',
#   'nowVal': 12075,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.04,
#   'nav': None,
#   'threeMonthEarnRate': 9.6686,
#   'quant': 82620,
#   'amonut': 998,
#   'marketSum': 857},
#  {'itemcode': '195930',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 유로스탁스50(합성 H)',
#   'nowVal': 14030,
#   'risefall': '2',
#   'changeVal': 140,
#   'changeRate': 1.01,
#   'nav': None,
#   'threeMonthEarnRate': 9.1552,
#   'quant': 37680,
#   'amonut': 527,
#   'marketSum': 828},
#  {'itemcode': '130680',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 원유선물Enhanced(H)',
#   'nowVal': 3330,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.15,
#   'nav': None,
#   'threeMonthEarnRate': 25.9469,
#   'quant': 484792,
#   'amonut': 1610,
#   'marketSum': 811},
#  {'itemcode': '174360',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 중국본토대형주CSI100',
#   'nowVal': 22295,
#   'risefall': '2',
#   'changeVal': 405,
#   'changeRate': 1.85,
#   'nav': None,
#   'threeMonthEarnRate': 1.9562,
#   'quant': 17809,
#   'amonut': 392,
#   'marketSum': 780},
#  {'itemcode': '309230',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 미국WideMoat가치주',
#   'nowVal': 16785,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.33,
#   'nav': None,
#   'threeMonthEarnRate': 8.4702,
#   'quant': 55324,
#   'amonut': 930,
#   'marketSum': 755},
#  {'itemcode': '139220',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 건설',
#   'nowVal': 3375,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.15,
#   'nav': 3377.0,
#   'threeMonthEarnRate': 20.4001,
#   'quant': 2461203,
#   'amonut': 8393,
#   'marketSum': 747},
#  {'itemcode': '195980',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#   'nowVal': 13180,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.57,
#   'nav': None,
#   'threeMonthEarnRate': 3.7608,
#   'quant': 24265,
#   'amonut': 320,
#   'marketSum': 746},
#  {'itemcode': '256750',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 심천ChiNext(합성)',
#   'nowVal': 14280,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 1.06,
#   'nav': None,
#   'threeMonthEarnRate': 22.6562,
#   'quant': 66903,
#   'amonut': 950,
#   'marketSum': 743},
#  {'itemcode': '157490',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 소프트웨어',
#   'nowVal': 19075,
#   'risefall': '5',
#   'changeVal': -225,
#   'changeRate': -1.17,
#   'nav': 19058.0,
#   'threeMonthEarnRate': 14.2349,
#   'quant': 187094,
#   'amonut': 3560,
#   'marketSum': 736},
#  {'itemcode': '261240',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물',
#   'nowVal': 10000,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.5,
#   'nav': 10002.0,
#   'threeMonthEarnRate': -0.0498,
#   'quant': 206066,
#   'amonut': 2061,
#   'marketSum': 736},
#  {'itemcode': '266160',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 고배당',
#   'nowVal': 13115,
#   'risefall': '2',
#   'changeVal': 195,
#   'changeRate': 1.51,
#   'nav': 13117.0,
#   'threeMonthEarnRate': 10.0979,
#   'quant': 125549,
#   'amonut': 1639,
#   'marketSum': 734},
#  {'itemcode': '304940',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100선물(H)',
#   'nowVal': 18220,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.33,
#   'nav': None,
#   'threeMonthEarnRate': 9.5295,
#   'quant': 50078,
#   'amonut': 912,
#   'marketSum': 720},
#  {'itemcode': '385520',
#   'etfTabCode': 2,
#   'itemname': 'KODEX K-미래차액티브',
#   'nowVal': 11115,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.41,
#   'nav': 11114.0,
#   'threeMonthEarnRate': None,
#   'quant': 269731,
#   'amonut': 2994,
#   'marketSum': 706},
#  {'itemcode': '123310',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 인버스',
#   'nowVal': 4070,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.49,
#   'nav': 4067.0,
#   'threeMonthEarnRate': -7.4661,
#   'quant': 302374,
#   'amonut': 1227,
#   'marketSum': 692},
#  {'itemcode': '245360',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나HSCEI',
#   'nowVal': 12905,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 1.02,
#   'nav': None,
#   'threeMonthEarnRate': -0.0392,
#   'quant': 10470,
#   'amonut': 134,
#   'marketSum': 671},
#  {'itemcode': '277630',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스피',
#   'nowVal': 33365,
#   'risefall': '2',
#   'changeVal': 200,
#   'changeRate': 0.6,
#   'nav': 33471.0,
#   'threeMonthEarnRate': 9.16,
#   'quant': 41584,
#   'amonut': 1386,
#   'marketSum': 667},
#  {'itemcode': '114820',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국채3년',
#   'nowVal': 110255,
#   'risefall': '5',
#   'changeVal': -150,
#   'changeRate': -0.14,
#   'nav': 110248.0,
#   'threeMonthEarnRate': -0.1628,
#   'quant': 301,
#   'amonut': 33,
#   'marketSum': 662},
#  {'itemcode': '289260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER MSCI KOREA ESG리더스',
#   'nowVal': 12425,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.12,
#   'nav': 12482.0,
#   'threeMonthEarnRate': 7.9318,
#   'quant': 7111,
#   'amonut': 88,
#   'marketSum': 656},
#  {'itemcode': '117680',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 철강',
#   'nowVal': 10445,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.1,
#   'nav': 10462.0,
#   'threeMonthEarnRate': 30.6825,
#   'quant': 589516,
#   'amonut': 6196,
#   'marketSum': 651},
#  {'itemcode': '266360',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 미디어&엔터테인먼트',
#   'nowVal': 25450,
#   'risefall': '5',
#   'changeVal': -315,
#   'changeRate': -1.22,
#   'nav': 25555.0,
#   'threeMonthEarnRate': 17.9176,
#   'quant': 474646,
#   'amonut': 12095,
#   'marketSum': 636},
#  {'itemcode': '363510',
#   'etfTabCode': 6,
#   'itemname': 'SMART KIS단기통안채',
#   'nowVal': 100340,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 100330.0,
#   'threeMonthEarnRate': 0.0897,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 636},
#  {'itemcode': '306520',
#   'etfTabCode': 3,
#   'itemname': 'HANARO 200선물인버스',
#   'nowVal': 8470,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.47,
#   'nav': 8457.0,
#   'threeMonthEarnRate': -7.4498,
#   'quant': 6309,
#   'amonut': 53,
#   'marketSum': 627},
#  {'itemcode': '102970',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 증권',
#   'nowVal': 8640,
#   'risefall': '2',
#   'changeVal': 205,
#   'changeRate': 2.43,
#   'nav': 8682.0,
#   'threeMonthEarnRate': 12.093,
#   'quant': 320255,
#   'amonut': 2754,
#   'marketSum': 609},
#  {'itemcode': '245340',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국다우존스30',
#   'nowVal': 19565,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.33,
#   'nav': None,
#   'threeMonthEarnRate': 5.5766,
#   'quant': 30330,
#   'amonut': 594,
#   'marketSum': 607},
#  {'itemcode': '336160',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 금융채액티브',
#   'nowVal': 102855,
#   'risefall': '5',
#   'changeVal': -140,
#   'changeRate': -0.14,
#   'nav': 102845.0,
#   'threeMonthEarnRate': -0.1406,
#   'quant': 20,
#   'amonut': 2,
#   'marketSum': 597},
#  {'itemcode': '361580',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 200TR',
#   'nowVal': 22485,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.42,
#   'nav': 22539.0,
#   'threeMonthEarnRate': 7.5666,
#   'quant': 435,
#   'amonut': 9,
#   'marketSum': 585},
#  {'itemcode': '379800',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500TR',
#   'nowVal': 10590,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.19,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 176604,
#   'amonut': 1871,
#   'marketSum': 582},
#  {'itemcode': '304780',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200선물레버리지',
#   'nowVal': 32290,
#   'risefall': '2',
#   'changeVal': 355,
#   'changeRate': 1.11,
#   'nav': 32278.0,
#   'threeMonthEarnRate': 15.7274,
#   'quant': 2674,
#   'amonut': 86,
#   'marketSum': 581},
#  {'itemcode': '329750',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국달러단기채권액티브',
#   'nowVal': 9665,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.57,
#   'nav': None,
#   'threeMonthEarnRate': 0.1029,
#   'quant': 73122,
#   'amonut': 707,
#   'marketSum': 560},
#  {'itemcode': '219390',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#   'nowVal': 4455,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 2.06,
#   'nav': None,
#   'threeMonthEarnRate': 24.0056,
#   'quant': 267062,
#   'amonut': 1186,
#   'marketSum': 557},
#  {'itemcode': '243880',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200IT레버리지',
#   'nowVal': 68130,
#   'risefall': '2',
#   'changeVal': 580,
#   'changeRate': 0.86,
#   'nav': 68586.0,
#   'threeMonthEarnRate': 7.4012,
#   'quant': 17320,
#   'amonut': 1188,
#   'marketSum': 545},
#  {'itemcode': '337140',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 코스피대형주',
#   'nowVal': 15500,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.62,
#   'nav': 15543.0,
#   'threeMonthEarnRate': 7.5617,
#   'quant': 2787,
#   'amonut': 43,
#   'marketSum': 543},
#  {'itemcode': '139230',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 중공업',
#   'nowVal': 3900,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.91,
#   'nav': 3922.0,
#   'threeMonthEarnRate': 30.9725,
#   'quant': 544782,
#   'amonut': 2138,
#   'marketSum': 541},
#  {'itemcode': '363580',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 200IT TR',
#   'nowVal': 14615,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.38,
#   'nav': 14656.0,
#   'threeMonthEarnRate': 3.1892,
#   'quant': 2274,
#   'amonut': 33,
#   'marketSum': 541},
#  {'itemcode': '387280',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 퓨처모빌리티액티브',
#   'nowVal': 10740,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.37,
#   'nav': 10739.0,
#   'threeMonthEarnRate': None,
#   'quant': 119970,
#   'amonut': 1292,
#   'marketSum': 538},
#  {'itemcode': '130730',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 단기자금',
#   'nowVal': 101065,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.02,
#   'nav': 101064.0,
#   'threeMonthEarnRate': 0.1089,
#   'quant': 85754,
#   'amonut': 8668,
#   'marketSum': 532},
#  {'itemcode': '305080',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국채10년선물',
#   'nowVal': 11535,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.56,
#   'nav': None,
#   'threeMonthEarnRate': 0.8257,
#   'quant': 36527,
#   'amonut': 421,
#   'marketSum': 531},
#  {'itemcode': '266370',
#   'etfTabCode': 2,
#   'itemname': 'KODEX IT',
#   'nowVal': 21050,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.36,
#   'nav': 21087.0,
#   'threeMonthEarnRate': 1.4804,
#   'quant': 17355,
#   'amonut': 365,
#   'marketSum': 526},
#  {'itemcode': '375770',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 탄소효율그린뉴딜',
#   'nowVal': 10500,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.48,
#   'nav': 10504.0,
#   'threeMonthEarnRate': 6.8507,
#   'quant': 7920,
#   'amonut': 83,
#   'marketSum': 525},
#  {'itemcode': '385560',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS국고채30년Enhanced',
#   'nowVal': 101785,
#   'risefall': '5',
#   'changeVal': -1620,
#   'changeRate': -1.57,
#   'nav': 101687.0,
#   'threeMonthEarnRate': None,
#   'quant': 230,
#   'amonut': 23,
#   'marketSum': 519},
#  {'itemcode': '371450',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#   'nowVal': 11345,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.18,
#   'nav': None,
#   'threeMonthEarnRate': 7.4196,
#   'quant': 35835,
#   'amonut': 406,
#   'marketSum': 513},
#  {'itemcode': '322400',
#   'etfTabCode': 2,
#   'itemname': 'HANARO e커머스',
#   'nowVal': 20555,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.02,
#   'nav': 20560.0,
#   'threeMonthEarnRate': 21.5616,
#   'quant': 276295,
#   'amonut': 5667,
#   'marketSum': 493},
#  {'itemcode': '310960',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 200TR',
#   'nowVal': 23420,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 0.56,
#   'nav': 23473.0,
#   'threeMonthEarnRate': 7.4014,
#   'quant': 22720,
#   'amonut': 532,
#   'marketSum': 492},
#  {'itemcode': '292190',
#   'etfTabCode': 1,
#   'itemname': 'KODEX KRX300',
#   'nowVal': 20150,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.42,
#   'nav': 20156.0,
#   'threeMonthEarnRate': 6.7968,
#   'quant': 12723,
#   'amonut': 256,
#   'marketSum': 484},
#  {'itemcode': '302190',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 중장기국채',
#   'nowVal': 52055,
#   'risefall': '5',
#   'changeVal': -235,
#   'changeRate': -0.45,
#   'nav': 52061.0,
#   'threeMonthEarnRate': -0.0669,
#   'quant': 1700,
#   'amonut': 88,
#   'marketSum': 468},
#  {'itemcode': '379810',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100TR',
#   'nowVal': 10660,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.14,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 128463,
#   'amonut': 1371,
#   'marketSum': 448},
#  {'itemcode': '329650',
#   'etfTabCode': 7,
#   'itemname': 'KODEX TRF3070',
#   'nowVal': 11190,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.18,
#   'nav': 11153.0,
#   'threeMonthEarnRate': 2.0018,
#   'quant': 43715,
#   'amonut': 489,
#   'marketSum': 448},
#  {'itemcode': '114460',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국고채3년',
#   'nowVal': 106345,
#   'risefall': '5',
#   'changeVal': -170,
#   'changeRate': -0.16,
#   'nav': 106299.0,
#   'threeMonthEarnRate': -0.1828,
#   'quant': 452,
#   'amonut': 48,
#   'marketSum': 415},
#  {'itemcode': '365000',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX인터넷K-뉴딜',
#   'nowVal': 12725,
#   'risefall': '5',
#   'changeVal': -165,
#   'changeRate': -1.28,
#   'nav': 12727.0,
#   'threeMonthEarnRate': 13.7185,
#   'quant': 134908,
#   'amonut': 1714,
#   'marketSum': 414},
#  {'itemcode': '272570',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 중장기국공채액티브',
#   'nowVal': 103225,
#   'risefall': '5',
#   'changeVal': -165,
#   'changeRate': -0.16,
#   'nav': 103204.0,
#   'threeMonthEarnRate': -0.323,
#   'quant': 21,
#   'amonut': 2,
#   'marketSum': 410},
#  {'itemcode': '228810',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 미디어컨텐츠',
#   'nowVal': 8265,
#   'risefall': '5',
#   'changeVal': -190,
#   'changeRate': -2.25,
#   'nav': 8262.0,
#   'threeMonthEarnRate': 21.7422,
#   'quant': 483409,
#   'amonut': 4004,
#   'marketSum': 409},
#  {'itemcode': '341850',
#   'etfTabCode': 7,
#   'itemname': 'TIGER KIS부동산인프라채권TR',
#   'nowVal': 5790,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.17,
#   'nav': 5787.0,
#   'threeMonthEarnRate': 10.2001,
#   'quant': 50793,
#   'amonut': 294,
#   'marketSum': 394},
#  {'itemcode': '227830',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스피',
#   'nowVal': 33540,
#   'risefall': '2',
#   'changeVal': 215,
#   'changeRate': 0.65,
#   'nav': 33545.0,
#   'threeMonthEarnRate': 9.8674,
#   'quant': 627969,
#   'amonut': 20995,
#   'marketSum': 386},
#  {'itemcode': '280930',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국러셀2000(H)',
#   'nowVal': 15165,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 1.1,
#   'nav': None,
#   'threeMonthEarnRate': 5.2631,
#   'quant': 62239,
#   'amonut': 943,
#   'marketSum': 379},
#  {'itemcode': '356540',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX KIS종합채권(AA-이상)액티브',
#   'nowVal': 98030,
#   'risefall': '5',
#   'changeVal': -225,
#   'changeRate': -0.23,
#   'nav': 98017.0,
#   'threeMonthEarnRate': -0.3803,
#   'quant': 8,
#   'amonut': 0,
#   'marketSum': 376},
#  {'itemcode': '256440',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 인도네시아MSCI(합성)',
#   'nowVal': 7950,
#   'risefall': '5',
#   'changeVal': -75,
#   'changeRate': -0.93,
#   'nav': None,
#   'threeMonthEarnRate': -6.4686,
#   'quant': 57522,
#   'amonut': 457,
#   'marketSum': 374},
#  {'itemcode': '354350',
#   'etfTabCode': 4,
#   'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#   'nowVal': 18195,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.14,
#   'nav': None,
#   'threeMonthEarnRate': 10.6914,
#   'quant': 38319,
#   'amonut': 697,
#   'marketSum': 373},
#  {'itemcode': '122260',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 통안채1년',
#   'nowVal': 101130,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.05,
#   'nav': 101127.0,
#   'threeMonthEarnRate': -0.0149,
#   'quant': 3588,
#   'amonut': 362,
#   'marketSum': 364},
#  {'itemcode': '304770',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 코스닥150',
#   'nowVal': 14300,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -0.69,
#   'nav': 14438.0,
#   'threeMonthEarnRate': 0.6641,
#   'quant': 4127,
#   'amonut': 59,
#   'marketSum': 363},
#  {'itemcode': '139270',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 금융',
#   'nowVal': 7390,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 2.5,
#   'nav': 7415.0,
#   'threeMonthEarnRate': 11.6099,
#   'quant': 131113,
#   'amonut': 964,
#   'marketSum': 361},
#  {'itemcode': '169950',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 중국본토 A50',
#   'nowVal': 23770,
#   'risefall': '2',
#   'changeVal': 255,
#   'changeRate': 1.08,
#   'nav': None,
#   'threeMonthEarnRate': 3.6131,
#   'quant': 12332,
#   'amonut': 291,
#   'marketSum': 357},
#  {'itemcode': '099140',
#   'etfTabCode': 4,
#   'itemname': 'KODEX China H',
#   'nowVal': 21900,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 0.76,
#   'nav': None,
#   'threeMonthEarnRate': 0.1382,
#   'quant': 25056,
#   'amonut': 546,
#   'marketSum': 350},
#  {'itemcode': '326230',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 내수주플러스',
#   'nowVal': 11485,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.17,
#   'nav': 11538.0,
#   'threeMonthEarnRate': 9.4301,
#   'quant': 84262,
#   'amonut': 970,
#   'marketSum': 347},
#  {'itemcode': '252420',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 200선물인버스2X',
#   'nowVal': 1845,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -1.07,
#   'nav': 1844.0,
#   'threeMonthEarnRate': -15.0342,
#   'quant': 424142,
#   'amonut': 780,
#   'marketSum': 341},
#  {'itemcode': '364990',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX게임K-뉴딜',
#   'nowVal': 10970,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.18,
#   'nav': 10980.0,
#   'threeMonthEarnRate': -1.8818,
#   'quant': 56477,
#   'amonut': 618,
#   'marketSum': 340},
#  {'itemcode': '385510',
#   'etfTabCode': 2,
#   'itemname': 'KODEX K-신재생에너지액티브',
#   'nowVal': 10415,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 10410.0,
#   'threeMonthEarnRate': None,
#   'quant': 122113,
#   'amonut': 1274,
#   'marketSum': 338},
#  {'itemcode': '359210',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스피TR',
#   'nowVal': 15290,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.49,
#   'nav': 15284.0,
#   'threeMonthEarnRate': 9.6971,
#   'quant': 12,
#   'amonut': 0,
#   'marketSum': 336},
#  {'itemcode': '114470',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 국고채3년',
#   'nowVal': 111975,
#   'risefall': '5',
#   'changeVal': -130,
#   'changeRate': -0.12,
#   'nav': 111931.0,
#   'threeMonthEarnRate': -0.107,
#   'quant': 63,
#   'amonut': 7,
#   'marketSum': 336},
#  {'itemcode': '123320',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 레버리지',
#   'nowVal': 27990,
#   'risefall': '2',
#   'changeVal': 300,
#   'changeRate': 1.08,
#   'nav': 28020.0,
#   'threeMonthEarnRate': 15.3509,
#   'quant': 50035,
#   'amonut': 1402,
#   'marketSum': 336},
#  {'itemcode': '385600',
#   'etfTabCode': 2,
#   'itemname': '네비게이터 친환경자동차밸류체인액티브',
#   'nowVal': 10790,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 10839.0,
#   'threeMonthEarnRate': None,
#   'quant': 63290,
#   'amonut': 686,
#   'marketSum': 334},
#  {'itemcode': '279530',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 고배당',
#   'nowVal': 10110,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.55,
#   'nav': 10147.0,
#   'threeMonthEarnRate': 14.1705,
#   'quant': 13465,
#   'amonut': 136,
#   'marketSum': 334},
#  {'itemcode': '269540',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG 미국S&P500(H)',
#   'nowVal': 17435,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.29,
#   'nav': None,
#   'threeMonthEarnRate': 9.0994,
#   'quant': 8760,
#   'amonut': 152,
#   'marketSum': 331},
#  {'itemcode': '276970',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P고배당커버드콜(합성 H)',
#   'nowVal': 10320,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.05,
#   'nav': None,
#   'threeMonthEarnRate': 4.0657,
#   'quant': 22389,
#   'amonut': 231,
#   'marketSum': 330},
#  {'itemcode': '138910',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 구리선물(H)',
#   'nowVal': 7905,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.76,
#   'nav': None,
#   'threeMonthEarnRate': 4.3912,
#   'quant': 67351,
#   'amonut': 533,
#   'marketSum': 324},
#  {'itemcode': '292160',
#   'etfTabCode': 1,
#   'itemname': 'TIGER KRX300',
#   'nowVal': 20115,
#   'risefall': '2',
#   'changeVal': 100,
#   'changeRate': 0.5,
#   'nav': 20133.0,
#   'threeMonthEarnRate': 6.667,
#   'quant': 1093,
#   'amonut': 21,
#   'marketSum': 322},
#  {'itemcode': '228790',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 화장품',
#   'nowVal': 4030,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 1.0,
#   'nav': 4031.0,
#   'threeMonthEarnRate': 4.1775,
#   'quant': 290312,
#   'amonut': 1171,
#   'marketSum': 318},
#  {'itemcode': '244580',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 바이오',
#   'nowVal': 14690,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.38,
#   'nav': 14780.0,
#   'threeMonthEarnRate': 0.0,
#   'quant': 94563,
#   'amonut': 1390,
#   'marketSum': 317},
#  {'itemcode': '137610',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 농산물선물Enhanced(H)',
#   'nowVal': 6205,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.08,
#   'nav': None,
#   'threeMonthEarnRate': 9.6374,
#   'quant': 29906,
#   'amonut': 186,
#   'marketSum': 316},
#  {'itemcode': '203780',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥바이오',
#   'nowVal': 21050,
#   'risefall': '2',
#   'changeVal': 100,
#   'changeRate': 0.48,
#   'nav': None,
#   'threeMonthEarnRate': 4.8811,
#   'quant': 13268,
#   'amonut': 279,
#   'marketSum': 316},
#  {'itemcode': '277540',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX S&P아시아TOP50',
# ...
#   'marketSum': 61},
#  {'itemcode': '215620',
#   'etfTabCode': 2,
#   'itemname': '흥국 S&P코리아로우볼',
#   'nowVal': 12770,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 0.87,
#   'nav': 12806.0,
#   'threeMonthEarnRate': 16.478,
#   'quant': 89,
#   'amonut': 1,
#   'marketSum': 61},
#  {'itemcode': '346000',
#   'etfTabCode': 6,
#   'itemname': 'HANARO KAP초장기국고채',
#   'nowVal': 46000,
#   'risefall': '5',
#   'changeVal': -290,
#   'changeRate': -0.63,
#   'nav': 46002.0,
#   'threeMonthEarnRate': -1.607,
#   'quant': 146,
#   'amonut': 6,
#   'marketSum': 61},
#  {'itemcode': '176710',
#   'etfTabCode': 6,
#   'itemname': '파워 중기국고채',
#   'nowVal': 100040,
#   'risefall': '5',
#   'changeVal': -115,
#   'changeRate': -0.11,
#   'nav': 100010.0,
#   'threeMonthEarnRate': -0.2043,
#   'quant': 16,
#   'amonut': 1,
#   'marketSum': 60},
#  {'itemcode': '342610',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년플래트너',
#   'nowVal': 49705,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.03,
#   'nav': 49702.0,
#   'threeMonthEarnRate': 0.3331,
#   'quant': 7,
#   'amonut': 0,
#   'marketSum': 60},
#  {'itemcode': '342620',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년플래트너2X',
#   'nowVal': 48945,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.07,
#   'nav': 48918.0,
#   'threeMonthEarnRate': 0.2151,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 59},
#  {'itemcode': '217790',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 가격조정',
#   'nowVal': 26640,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 0.79,
#   'nav': 26636.0,
#   'threeMonthEarnRate': 3.8343,
#   'quant': 8,
#   'amonut': 0,
#   'marketSum': 59},
#  {'itemcode': '302180',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국채선물10년인버스',
#   'nowVal': 48375,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 48586.0,
#   'threeMonthEarnRate': 0.2486,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 58},
#  {'itemcode': '261260',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물인버스2X',
#   'nowVal': 9765,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 1.3,
#   'nav': 9764.0,
#   'threeMonthEarnRate': -0.5674,
#   'quant': 32275,
#   'amonut': 314,
#   'marketSum': 58},
#  {'itemcode': '269530',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG S&P글로벌인프라',
#   'nowVal': 11470,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.61,
#   'nav': None,
#   'threeMonthEarnRate': 7.0997,
#   'quant': 193,
#   'amonut': 2,
#   'marketSum': 57},
#  {'itemcode': '267440',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물(H)',
#   'nowVal': 11455,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.13,
#   'nav': None,
#   'threeMonthEarnRate': 2.8776,
#   'quant': 906,
#   'amonut': 10,
#   'marketSum': 57},
#  {'itemcode': '290080',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200고배당커버드콜ATM',
#   'nowVal': 8180,
#   'risefall': '2',
#   'changeVal': 115,
#   'changeRate': 1.43,
#   'nav': 8173.0,
#   'threeMonthEarnRate': 8.4734,
#   'quant': 661,
#   'amonut': 5,
#   'marketSum': 57},
#  {'itemcode': '380340',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX Fn5G플러스',
#   'nowVal': 9355,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.21,
#   'nav': 9378.0,
#   'threeMonthEarnRate': None,
#   'quant': 12177,
#   'amonut': 114,
#   'marketSum': 56},
#  {'itemcode': '140570',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 수출주',
#   'nowVal': 13920,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 0.8,
#   'nav': 13953.0,
#   'threeMonthEarnRate': 14.2455,
#   'quant': 38490,
#   'amonut': 536,
#   'marketSum': 56},
#  {'itemcode': '261920',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 필리핀MSCI(합성)',
#   'nowVal': 13840,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.58,
#   'nav': None,
#   'threeMonthEarnRate': 6.708,
#   'quant': 520,
#   'amonut': 7,
#   'marketSum': 55},
#  {'itemcode': '285010',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200중공업',
#   'nowVal': 12010,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 1.01,
#   'nav': 12028.0,
#   'threeMonthEarnRate': 30.803,
#   'quant': 11180,
#   'amonut': 134,
#   'marketSum': 55},
#  {'itemcode': '321410',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 멀티에셋하이인컴(H)',
#   'nowVal': 10850,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': None,
#   'threeMonthEarnRate': 4.2767,
#   'quant': 2419,
#   'amonut': 25,
#   'marketSum': 54},
#  {'itemcode': '269370',
#   'etfTabCode': 4,
#   'itemname': 'TIGER S&P글로벌인프라(합성)',
#   'nowVal': 10670,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.23,
#   'nav': None,
#   'threeMonthEarnRate': 5.1002,
#   'quant': 3386,
#   'amonut': 36,
#   'marketSum': 53},
#  {'itemcode': '314700',
#   'etfTabCode': 2,
#   'itemname': 'HANARO 농업융복합산업',
#   'nowVal': 13335,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 0.83,
#   'nav': 13324.0,
#   'threeMonthEarnRate': 10.2083,
#   'quant': 708,
#   'amonut': 9,
#   'marketSum': 53},
#  {'itemcode': '304670',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국채울트라30년선물인버스(H)',
#   'nowVal': 7550,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.46,
#   'nav': None,
#   'threeMonthEarnRate': -4.1693,
#   'quant': 38092,
#   'amonut': 287,
#   'marketSum': 53},
#  {'itemcode': '371870',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 차이나항셍테크',
#   'nowVal': 10200,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 1.85,
#   'nav': None,
#   'threeMonthEarnRate': -0.05,
#   'quant': 5754,
#   'amonut': 58,
#   'marketSum': 51},
#  {'itemcode': '292770',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국채선물3년인버스',
#   'nowVal': 49920,
#   'risefall': '2',
#   'changeVal': 100,
#   'changeRate': 0.2,
#   'nav': 49953.0,
#   'threeMonthEarnRate': 0.2616,
#   'quant': 10,
#   'amonut': 0,
#   'marketSum': 51},
#  {'itemcode': '220130',
#   'etfTabCode': 4,
#   'itemname': 'SMART 중국본토 중소형 CSI500(합성 H)',
#   'nowVal': 5655,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.8,
#   'nav': None,
#   'threeMonthEarnRate': 9.1439,
#   'quant': 2671,
#   'amonut': 15,
#   'marketSum': 51},
#  {'itemcode': '295000',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물10년',
#   'nowVal': 55255,
#   'risefall': '5',
#   'changeVal': -245,
#   'changeRate': -0.44,
#   'nav': 55233.0,
#   'threeMonthEarnRate': -0.0361,
#   'quant': 130,
#   'amonut': 7,
#   'marketSum': 51},
#  {'itemcode': '261270',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물인버스',
#   'nowVal': 10155,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.74,
#   'nav': 10155.0,
#   'threeMonthEarnRate': -0.4936,
#   'quant': 1551,
#   'amonut': 15,
#   'marketSum': 51},
#  {'itemcode': '280920',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 주도업종',
#   'nowVal': 12660,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.31,
#   'nav': 12649.0,
#   'threeMonthEarnRate': 10.685,
#   'quant': 3863,
#   'amonut': 48,
#   'marketSum': 51},
#  {'itemcode': '299080',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국채선물3년인버스',
#   'nowVal': 99595,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 99879.0,
#   'threeMonthEarnRate': 0.2365,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 50},
#  {'itemcode': '250730',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 차이나HSCEI(H)',
#   'nowVal': 12400,
#   'risefall': '2',
#   'changeVal': 255,
#   'changeRate': 2.1,
#   'nav': None,
#   'threeMonthEarnRate': -1.4205,
#   'quant': 1847,
#   'amonut': 22,
#   'marketSum': 50},
#  {'itemcode': '309210',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KRX300헬스케어',
#   'nowVal': 13495,
#   'risefall': '5',
#   'changeVal': -175,
#   'changeRate': -1.28,
#   'nav': 13594.0,
#   'threeMonthEarnRate': 0.0,
#   'quant': 906,
#   'amonut': 12,
#   'marketSum': 49},
#  {'itemcode': '299070',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국채선물10년인버스',
#   'nowVal': 95245,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 95859.0,
#   'threeMonthEarnRate': -0.2096,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 48},
#  {'itemcode': '139310',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 금속선물(H)',
#   'nowVal': 6800,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 1.04,
#   'nav': None,
#   'threeMonthEarnRate': 8.9878,
#   'quant': 4670,
#   'amonut': 31,
#   'marketSum': 48},
#  {'itemcode': '275750',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150선물인버스',
#   'nowVal': 4730,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.96,
#   'nav': 4718.0,
#   'threeMonthEarnRate': -2.5988,
#   'quant': 7009,
#   'amonut': 32,
#   'marketSum': 47},
#  {'itemcode': '296710',
#   'etfTabCode': 2,
#   'itemname': 'KODEX FnKorea50',
#   'nowVal': 11545,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 11649.0,
#   'threeMonthEarnRate': 10.5419,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 46},
#  {'itemcode': '301410',
#   'etfTabCode': 3,
#   'itemname': 'ARIRANG 코스닥150선물인버스',
#   'nowVal': 7065,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.36,
#   'nav': 7077.0,
#   'threeMonthEarnRate': -1.9499,
#   'quant': 15620,
#   'amonut': 109,
#   'marketSum': 46},
#  {'itemcode': '334690',
#   'etfTabCode': 5,
#   'itemname': 'KBSTAR 팔라듐선물(H)',
#   'nowVal': 15190,
#   'risefall': '2',
#   'changeVal': 190,
#   'changeRate': 1.27,
#   'nav': None,
#   'threeMonthEarnRate': -0.1,
#   'quant': 4668,
#   'amonut': 70,
#   'marketSum': 46},
#  {'itemcode': '227560',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 생활소비재',
#   'nowVal': 12350,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.49,
#   'nav': 12365.0,
#   'threeMonthEarnRate': 6.0946,
#   'quant': 5068,
#   'amonut': 62,
#   'marketSum': 44},
#  {'itemcode': '280940',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 골드선물인버스(H)',
#   'nowVal': 7330,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.14,
#   'nav': None,
#   'threeMonthEarnRate': -3.0384,
#   'quant': 4854,
#   'amonut': 35,
#   'marketSum': 44},
#  {'itemcode': '291620',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 코스닥150선물인버스',
#   'nowVal': 8110,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.43,
#   'nav': 8114.0,
#   'threeMonthEarnRate': -2.0619,
#   'quant': 96,
#   'amonut': 0,
#   'marketSum': 43},
#  {'itemcode': '266550',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 중형주저변동50',
#   'nowVal': 12150,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 1.25,
#   'nav': 12155.0,
#   'threeMonthEarnRate': 10.2029,
#   'quant': 196,
#   'amonut': 2,
#   'marketSum': 43},
#  {'itemcode': '333980',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KS퀄리티가중TR',
#   'nowVal': 16530,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.43,
#   'nav': 16526.0,
#   'threeMonthEarnRate': 7.1265,
#   'quant': 10151,
#   'amonut': 167,
#   'marketSum': 41},
#  {'itemcode': '140580',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 우량업종',
#   'nowVal': 13535,
#   'risefall': '2',
#   'changeVal': 135,
#   'changeRate': 1.01,
#   'nav': 13602.0,
#   'threeMonthEarnRate': 16.3396,
#   'quant': 35,
#   'amonut': 0,
#   'marketSum': 41},
#  {'itemcode': '267450',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#   'nowVal': 8120,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.06,
#   'nav': None,
#   'threeMonthEarnRate': -3.6181,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 41},
#  {'itemcode': '295020',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물10년인버스',
#   'nowVal': 47870,
#   'risefall': '2',
#   'changeVal': 240,
#   'changeRate': 0.5,
#   'nav': 47844.0,
#   'threeMonthEarnRate': 0.1998,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 40},
#  {'itemcode': '278420',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG ESG우수기업',
#   'nowVal': 9990,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.91,
#   'nav': 10005.0,
#   'threeMonthEarnRate': 12.5127,
#   'quant': 3878,
#   'amonut': 38,
#   'marketSum': 40},
#  {'itemcode': '284990',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200에너지화학',
#   'nowVal': 14215,
#   'risefall': '2',
#   'changeVal': 135,
#   'changeRate': 0.96,
#   'nav': 14215.0,
#   'threeMonthEarnRate': 13.5667,
#   'quant': 1236,
#   'amonut': 17,
#   'marketSum': 40},
#  {'itemcode': '252720',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 모멘텀밸류',
#   'nowVal': 15770,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.41,
#   'nav': 15839.0,
#   'threeMonthEarnRate': 8.1462,
#   'quant': 275,
#   'amonut': 4,
#   'marketSum': 39},
#  {'itemcode': '253240',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 200선물인버스',
#   'nowVal': 4765,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.42,
#   'nav': 4754.0,
#   'threeMonthEarnRate': -7.7146,
#   'quant': 8077,
#   'amonut': 38,
#   'marketSum': 39},
#  {'itemcode': '217770',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 원유선물인버스(H)',
#   'nowVal': 5885,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.08,
#   'nav': None,
#   'threeMonthEarnRate': -22.7541,
#   'quant': 6625,
#   'amonut': 38,
#   'marketSum': 38},
#  {'itemcode': '291660',
#   'etfTabCode': 4,
#   'itemname': 'KODEX China H선물인버스(H)',
#   'nowVal': 9480,
#   'risefall': '5',
#   'changeVal': -200,
#   'changeRate': -2.07,
#   'nav': None,
#   'threeMonthEarnRate': 0.1034,
#   'quant': 193,
#   'amonut': 1,
#   'marketSum': 38},
#  {'itemcode': '267490',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#   'nowVal': 12605,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.44,
#   'nav': None,
#   'threeMonthEarnRate': 5.4621,
#   'quant': 2,
#   'amonut': 0,
#   'marketSum': 38},
#  {'itemcode': '291680',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 차이나H선물인버스(H)',
#   'nowVal': 9345,
#   'risefall': '5',
#   'changeVal': -155,
#   'changeRate': -1.63,
#   'nav': None,
#   'threeMonthEarnRate': -0.7833,
#   'quant': 68,
#   'amonut': 0,
#   'marketSum': 37},
#  {'itemcode': '287300',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200건설',
#   'nowVal': 13690,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.15,
#   'nav': 13681.0,
#   'threeMonthEarnRate': 20.6531,
#   'quant': 6690,
#   'amonut': 92,
#   'marketSum': 36},
#  {'itemcode': '291890',
#   'etfTabCode': 4,
#   'itemname': 'KODEX MSCI EM선물(H)',
#   'nowVal': 11060,
#   'risefall': '2',
#   'changeVal': 170,
#   'changeRate': 1.56,
#   'nav': None,
#   'threeMonthEarnRate': 4.9132,
#   'quant': 302,
#   'amonut': 3,
#   'marketSum': 33},
#  {'itemcode': '284980',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200금융',
#   'nowVal': 9395,
#   'risefall': '2',
#   'changeVal': 225,
#   'changeRate': 2.45,
#   'nav': 9420.0,
#   'threeMonthEarnRate': 12.0068,
#   'quant': 9383,
#   'amonut': 87,
#   'marketSum': 32},
#  {'itemcode': '301400',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스닥150',
#   'nowVal': 14415,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.07,
#   'nav': 14415.0,
#   'threeMonthEarnRate': 0.5927,
#   'quant': 356,
#   'amonut': 5,
#   'marketSum': 29},
#  {'itemcode': '287330',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200생활소비재',
#   'nowVal': 9410,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.64,
#   'nav': 9422.0,
#   'threeMonthEarnRate': 5.5543,
#   'quant': 3918,
#   'amonut': 36,
#   'marketSum': 28},
#  {'itemcode': '309170',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KRX300IT',
#   'nowVal': 19400,
#   'risefall': '2',
#   'changeVal': 190,
#   'changeRate': 0.99,
#   'nav': 19417.0,
#   'threeMonthEarnRate': 1.1958,
#   'quant': 243,
#   'amonut': 4,
#   'marketSum': 27},
#  {'itemcode': '285020',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200철강소재',
#   'nowVal': 9945,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.25,
#   'nav': 9966.0,
#   'threeMonthEarnRate': 27.654,
#   'quant': 6791,
#   'amonut': 67,
#   'marketSum': 26},
#  {'itemcode': '306540',
#   'etfTabCode': 6,
#   'itemname': 'HANARO 단기통안채',
#   'nowVal': 103070,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 103077.0,
#   'threeMonthEarnRate': 0.0776,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 23},
#  {'itemcode': '267500',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#   'nowVal': 6360,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.7,
#   'nav': None,
#   'threeMonthEarnRate': -6.1539,
#   'quant': 5110,
#   'amonut': 32,
#   'marketSum': 22},
#  {'itemcode': '287310',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200경기소비재',
#   'nowVal': 12455,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.32,
#   'nav': 12529.0,
#   'threeMonthEarnRate': 9.1716,
#   'quant': 561,
#   'amonut': 6,
#   'marketSum': 17},
#  {'itemcode': '287320',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200산업재',
#   'nowVal': 13415,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 1.25,
#   'nav': 13490.0,
#   'threeMonthEarnRate': 16.463,
#   'quant': 1585,
#   'amonut': 21,
#   'marketSum': 16},
#  {'itemcode': '334700',
#   'etfTabCode': 5,
#   'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#   'nowVal': 4535,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.55,
#   'nav': None,
#   'threeMonthEarnRate': -3.7975,
#   'quant': 115,
#   'amonut': 0,
#   'marketSum': 14}]

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
df=pd.DataFrame(etfItemList)
df
# Out:
#     itemcode  etfTabCode                    itemname  nowVal risefall  \
# 0     069500           1                   KODEX 200   43955        2
# 1     153130           6                  KODEX 단기채권  102805        5
# 2     252670           3            KODEX 200선물인버스2X    1845        5
# 3     102110           1                   TIGER 200   43985        2
# 4     102780           2                  KODEX 삼성그룹   10285        2
# ..       ...         ...                         ...     ...      ...
# 477   306540           6                HANARO 단기통안채  103070        3
# 478   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    6360        5
# 479   287310           2             KBSTAR 200경기소비재   12455        2
# 480   287320           2               KBSTAR 200산업재   13415        2
# 481   334700           5          KBSTAR 팔라듐선물인버스(H)    4535        5
#
#      changeVal  changeRate       nav  threeMonthEarnRate      quant  amonut  \
# 0          220        0.50   44047.0              7.4517    2655205  116819
# 1          -10       -0.01  102803.0              0.0535      22011    2262
# 2          -15       -0.81    1844.0            -15.2620  146475126  269418
# 3          215        0.49   44081.0              7.4928     530566   23370
# 4           15        0.15   10323.0              7.4492     265587    2741
# ..         ...         ...       ...                 ...        ...     ...
# 477          0        0.00  103077.0              0.0776          0       0
# 478        -45       -0.70       NaN             -6.1539       5110      32
# 479         40        0.32   12529.0              9.1716        561       6
# 480        165        1.25   13490.0             16.4630       1585      21
# 481        -25       -0.55       NaN             -3.7975        115       0
#
#      marketSum
# 0        39933
# 1        24415
# 2        22304
# 3        22036
# 4        18852
# ..         ...
# 477         23
# 478         22
# 479         17
# 480         16
# 481         14
#
# [482 rows x 12 columns]

# %% [markdown]
# ### 데이터 확인

# %%
df.head()
# Out:
#   itemcode  etfTabCode          itemname  nowVal risefall  changeVal  \
# 0   069500           1         KODEX 200   43955        2        220
# 1   153130           6        KODEX 단기채권  102805        5        -10
# 2   252670           3  KODEX 200선물인버스2X    1845        5        -15
# 3   102110           1         TIGER 200   43985        2        215
# 4   102780           2        KODEX 삼성그룹   10285        2         15
#
#    changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0        0.50   44047.0              7.4517    2655205  116819      39933
# 1       -0.01  102803.0              0.0535      22011    2262      24415
# 2       -0.81    1844.0            -15.2620  146475126  269418      22304
# 3        0.49   44081.0              7.4928     530566   23370      22036
# 4        0.15   10323.0              7.4492     265587    2741      18852

# %%
df.tail()
# Out:
#     itemcode  etfTabCode                    itemname  nowVal risefall  \
# 477   306540           6                HANARO 단기통안채  103070        3
# 478   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    6360        5
# 479   287310           2             KBSTAR 200경기소비재   12455        2
# 480   287320           2               KBSTAR 200산업재   13415        2
# 481   334700           5          KBSTAR 팔라듐선물인버스(H)    4535        5
#
#      changeVal  changeRate       nav  threeMonthEarnRate  quant  amonut  \
# 477          0        0.00  103077.0              0.0776      0       0
# 478        -45       -0.70       NaN             -6.1539   5110      32
# 479         40        0.32   12529.0              9.1716    561       6
# 480        165        1.25   13490.0             16.4630   1585      21
# 481        -25       -0.55       NaN             -3.7975    115       0
#
#      marketSum
# 477         23
# 478         22
# 479         17
# 480         16
# 481         14

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
import datetime

today=datetime.datetime.today().strftime("%Y-%m-%d")
today
# Out:
# '2021-06-26'

# %%
file_name=f"etf_{today}_raw.csv"
file_name
# Out:
# 'etf_2021-06-26_raw.csv'

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
df.to_csv(file_name,index=False)

# %%
pd.read_csv("etf_2021-06-26_raw.csv")
# Out:
#      itemcode  etfTabCode                    itemname  nowVal  risefall  \
# 0       69500           1                   KODEX 200   43955         2
# 1      153130           6                  KODEX 단기채권  102805         5
# 2      252670           3            KODEX 200선물인버스2X    1845         5
# 3      102110           1                   TIGER 200   43985         2
# 4      102780           2                  KODEX 삼성그룹   10285         2
# ..        ...         ...                         ...     ...       ...
# 477    306540           6                HANARO 단기통안채  103070         3
# 478    267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    6360         5
# 479    287310           2             KBSTAR 200경기소비재   12455         2
# 480    287320           2               KBSTAR 200산업재   13415         2
# 481    334700           5          KBSTAR 팔라듐선물인버스(H)    4535         5
#
#      changeVal  changeRate       nav  threeMonthEarnRate      quant  amonut  \
# 0          220        0.50   44047.0              7.4517    2655205  116819
# 1          -10       -0.01  102803.0              0.0535      22011    2262
# 2          -15       -0.81    1844.0            -15.2620  146475126  269418
# 3          215        0.49   44081.0              7.4928     530566   23370
# 4           15        0.15   10323.0              7.4492     265587    2741
# ..         ...         ...       ...                 ...        ...     ...
# 477          0        0.00  103077.0              0.0776          0       0
# 478        -45       -0.70       NaN             -6.1539       5110      32
# 479         40        0.32   12529.0              9.1716        561       6
# 480        165        1.25   13490.0             16.4630       1585      21
# 481        -25       -0.55       NaN             -3.7975        115       0
#
#      marketSum
# 0        39933
# 1        24415
# 2        22304
# 3        22036
# 4        18852
# ..         ...
# 477         23
# 478         22
# 479         17
# 480         16
# 481         14
#
# [482 rows x 12 columns]
