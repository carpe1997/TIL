# %% [markdown]
# ## 라이브러리 불러오기

# %%
import pandas as pd

# %% [markdown]
# * [FinanceData/FinanceDataReader: Financial data reader](https://github.com/FinanceData/FinanceDataReader)
# * [FinanceDataReader 사용자 안내서 | FinanceData](https://financedata.github.io/posts/finance-data-reader-users-guide.html)

# %%
# !pip install -U finance-datareader

# %%
# FinanceDataReader 를 fdr 별칭으로 가져오기
import FinanceDataReader as fdr

# %% [markdown]
# ## 개별 종목의 일별 시세 수집
# * 종목코드로 수집이 가능합니다.
# * 종목명을 찾아서 일별 시세를 수집해 주는 함수를 만들어 볼 예정입니다.

# %%
df=fdr.DataReader("005930","2017","2022")
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2017-01-02  35980  36240  35880  36100     93012  0.001665
# 2017-01-03  36280  36620  36020  36480    147153  0.010526
# 2017-01-04  36500  36520  36100  36160    159435 -0.008772
# 2017-01-05  36060  36060  35540  35560    219349 -0.016593
# 2017-01-06  36180  36440  36040  36200    177619  0.017998
# ...           ...    ...    ...    ...       ...       ...
# 2021-06-18  81100  81100  80500  80500  14916721 -0.004944
# 2021-06-21  79700  80000  79600  79900  16063340 -0.007453
# 2021-06-22  80200  80300  79900  80000  11773365  0.001252
# 2021-06-23  80500  80600  79900  80100  13856548  0.001250
# 2021-06-24  80400  81400  80100  81200  18482196  0.013733
#
# [1100 rows x 6 columns]

# %%
# 종가 시각화 하기
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 상장종목 목록 가져오기

# %%
df_krx=pd.read_csv("krx.csv")
df_krx
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 7146  000547   KOSPI  흥국화재2우B                       NaN
# 7147  000545   KOSPI    흥국화재우                       NaN
# 7148  003280   KOSPI     흥아해운                    해상 운송업
# 7149  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7150  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# ...

# %% [markdown]
# ## 상장종목 목록 사용하기
# * 종목명과 심볼을 찾기 위해 상장종목 목록을 사용합니다.

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 박대현         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %% [markdown]
# ## 종목명으로 종목 코드를 받아오는 함수 만들기

# %%
def item_code_by_item_name(item_name):
    item_code=df_krx.loc[df_krx["Name"]==item_name,"Symbol"].tolist()[0]
    return item_code

# %%
item_code_by_item_name("하이브")
# Out:
# '352820'

# %%
item_code_by_item_name("NAVER")
# Out:
# '035420'

# %%
item_code_by_item_name("삼성전자")
# Out:
# '005930'

# %%
item_code_by_item_name("셀트리온")
# Out:
# '068270'

# %%
item_code_by_item_name("박셀바이오")
# Out:
# '323990'

# %% [markdown]
# ## 종목명으로 일별시세를 받아오는 함수 만들기

# %%
def find_item_list(item_name, year=2020):
    item_code=item_code_by_item_name(item_name)
    if item_code:
        df_day=fdr.DataReader(item_code,year)
        return df_day
    else:
        return False

# %%
find_item_list("박셀바이오")
# Out:
#              Open   High    Low  Close   Volume    Change
# Date
# 2020-09-22  13500  13500  10375  10650  4090940       NaN
# 2020-09-23  11075  13825  11025  12750  8921196  0.197183
# 2020-09-24  12225  15600  12000  13250  8325838  0.039216
# 2020-09-25  13550  15250  13000  13475  4612185  0.016981
# 2020-09-28  13900  14575  13525  14000  1628177  0.038961
# ...           ...    ...    ...    ...      ...       ...
# 2021-06-18  93000  95400  92100  93500   377428  0.009719
# 2021-06-21  92600  93000  91700  91900   184342 -0.017112
# 2021-06-22  92400  92600  91600  91600   152428 -0.003264
# 2021-06-23  91800  92100  90900  91200   224965 -0.004367
# 2021-06-24  91300  94000  90800  92000   318722  0.008772
#
# [186 rows x 6 columns]

# %% [markdown]
# ### 종목명으로 일별 시세를 잘 가져오는지 확인하기

# %%
find_item_list("LG화학")
# Out:
#               Open    High     Low   Close   Volume    Change
# Date
# 2001-04-25   20621   20621   17563   18489  3094940       NaN
# 2001-04-26   17918   18416   17492   17636  1197840 -0.046136
# 2001-04-27   17280   18204   17066   18062   854340  0.024155
# 2001-04-30   17706   18275   17706   18204   803230  0.007862
# 2001-05-02   18345   18843   17990   18489   851580  0.015656
# ...            ...     ...     ...     ...      ...       ...
# 2021-06-18  835000  840000  821000  822000   252978 -0.015569
# 2021-06-21  812000  826000  807000  822000   144762  0.000000
# 2021-06-22  825000  844000  824000  842000   243411  0.024331
# 2021-06-23  846000  846000  825000  835000   220075 -0.008314
# 2021-06-24  837000  839000  827000  831000   187765 -0.004790
#
# [4986 rows x 6 columns]

# %%
stock_daily=find_item_list("하이브")
stock_daily
# Out:
#               Open    High     Low   Close   Volume    Change
# Date
# 2020-10-15  267300  347490  250965  255420  6557212       NaN
# 2020-10-16  250469  250469  197010  198495  4504395 -0.222868
# 2020-10-19  196515  200475  185129  187110  1977996 -0.057357
# 2020-10-20  188100  191565  174240  180675  1811616 -0.034392
# 2020-10-21  178695  183645  175230  177210  1658643 -0.019178
# ...            ...     ...     ...     ...      ...       ...
# 2021-06-18  298500  326500  297500  313000  1630734  0.053872
# 2021-06-21  313000  321000  299500  308000   556480 -0.015974
# 2021-06-22  311000  324500  311000  324500   607966  0.053571
# 2021-06-23  334500  337000  318500  321500   687701 -0.009245
# 2021-06-24  326000  329500  317500  322000   373105  0.001555
#
# [173 rows x 6 columns]

# %% [markdown]
# ## 개별종목 시세 시각화
# ### pandas 의 plot으로 시각화 하기

# %%
stock_daily["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_daily.plot(secondary_y="Volume",figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 서브플롯 그리기

# %%
stock_daily.plot(subplots=True,figsize=(10,8))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
k=stock_daily.hist(figsize=(10,6))

# %%
k=stock_daily.hist(figsize=(10,6),bins=50)

# %% [markdown]
# ### 2축 그래프 그리기

# %%
# secondary_y 옵션을 통한 종가와 거래량에 대한 2축 그래프 그리기
k=stock_daily[["Close","Volume"]].plot(secondary_y="Volume",figsize=(10,10))
